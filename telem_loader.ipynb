# %%
import fastf1
import pandas as pd

# %%
#cyfronet version
fastf1.Cache.enable_cache('cache')
gps = [
'Saudi', 'Australia', 'Azerbaijan', 'Miami', 'Monaco', 'Spain', 'Canada', 'Austria',
'Great Britain', 'Hungary', 'Belgium', 'Netherlands', 'Italy', 'Singapore', 'Japan', 'Qatar',
'USA', 'Mexico', 'Brazil', 'Las Vegas', 'Abu Dhabi'
]
for gp in gps:
    session = fastf1.get_session(2023, gp, 'R')
    session.load(telemetry=True)
    laps = session.laps

    telemetry_data = []
    for _, lap in laps.iterrows():
        tel = lap.get_telemetry()
        tel['DriverNumber'] = lap['DriverNumber']  
        tel['LapNumber'] = lap['LapNumber']
        telemetry_data.append(tel)

    telemetry_df = pd.concat(telemetry_data, ignore_index=True)
    telemetry_df.to_pickle(gp)
# Out:
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core        WARNING 	Driver 1 completed the race distance 00:00.076000 before the recorded end of the session.
# ...

# %%
full_df.to_pickle('../data_telemetry/2023_full_telemetry.pkl')

# %%
full_df.head()
# Out:
#                      Date            SessionTime DriverAhead  \
# 0 2023-11-26 13:03:25.644 0 days 01:02:24.519000
# 1 2023-11-26 13:03:25.847 0 days 01:02:24.722000
# 2 2023-11-26 13:03:25.868 0 days 01:02:24.743000
# 3 2023-11-26 13:03:26.289 0 days 01:02:25.164000
# 4 2023-11-26 13:03:26.327 0 days 01:02:25.202000          16
#
#    DistanceToDriverAhead                   Time           RPM      Speed  \
# 0                    0.0        0 days 00:00:00  10105.516685   0.000000
# 1                    0.0 0 days 00:00:00.203000  10048.000000   0.000000
# 2                    0.0 0 days 00:00:00.224000   9950.000299   0.481249
# 3                    0.0 0 days 00:00:00.645000   7985.333931  10.129164
# 4                    0.0 0 days 00:00:00.683000   7808.000000  11.000000
#
#    nGear   Throttle  Brake  DRS         Source  Distance  RelativeDistance  \
# 0      1  15.845834   True    1  interpolation -0.033609         -0.000007
# ...
